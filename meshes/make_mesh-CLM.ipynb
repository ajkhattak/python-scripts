# %%
# %matplotlib

# %%
import sys, os

sys.path.append(os.path.join(os.environ['ATS_SRC_DIR'],'tools','meshing_ats'))
import meshing_ats

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
reload(meshing_ats)
#READ VTK
mesh_name = 'coweeta_basin2-fine'
infile= '/Users/ajc/Desktop/ATS/CoweetaLTER/mesh/watershed/coweeta_basin2-fine.vtk' #_basin_coarse.vtk'
m2 =meshing_ats.Mesh2D.read_VTK_Unstructured(infile)
#m2 =meshing_ats.Mesh2D.read_VTK(infile)

# Read ELM column mesh vtk
#infile= '/Users/ajc/Desktop/ATS/meshes/ELM_Comp/mesh_column-clm.vtk'
#m2 =meshing_ats.Mesh2D.read_VTK_Unstructured(infile)
# Out:
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# 3 3
# ...

# %%
# From a fucntion
# To get topography from a function, define it here, e.g., z = sine(x)

x = np.linspace(0,500,501)
x0,z0 = 0, 0
z = z0 + 0.25 * (x - x0)

plt.plot(x, z, '.')
#plt.title('Coweeta watershed')
plt.show()
m2 = meshing_ats.Mesh2D.from_Transect(x,z)

# %%
outfile= '/Users/ajc/Desktop/ATS/CoweetaLTER/mesh/'

#CLM vertical resolution

# layer extrusion
layer_types = []
layer_data = []
layer_ncells = []
layer_mat_ids = []

dz_res = [  0.01751282,0.02757897,0.04547003,0.07496741,0.1236004,0.2037826,0.3359806,0.5539384,0.91329,
         1.505761,2.48258,4.093082,6.748351,11.12615,13.85115] # cell center to center distance

z_res = [0, 0.007100635, 0.027925, 0.06225858,0.1188651,0.2121934,0.3660658,0.6197585,1.038027,1.727635,2.864607, 4.739157]

z_depth = np.sum(z_res)

print z_depth
ind = 1001
for i,z in enumerate(z_res):
    layer_types.append('constant')
    layer_data.append(z)
    layer_ncells.append(1)
    if i ==1:
        ind = 1002
    if (i ==2) :
        ind = 1003
    #print ind
    layer_mat_ids.append(ind)

#layer_types.append('constant')
#layer_data.append(z_res[-1]) # bottom location
"""
layer_types.append('snapped')
layer_data.append(-z_depth) # bottom location
"""
#layer_ncells.append(1)
#layer_mat_ids.append(ind)
print layer_data
m3 = meshing_ats.Mesh3D.extruded_Mesh2D(m2, layer_types, 
                                        layer_data, 
                                        layer_ncells, 
                                        layer_mat_ids)
#m3.write_exodus(outfile + mesh_name + ".exo")
#m3.write_exodus(outfile + "coweeta-hillslope-clmres.exo")

# %%
outfile= '/Users/ajc/Desktop/ATS/CoweetaLTER/mesh/'

#CLM vertical resolution

# layer extrusion
layer_types = []
layer_data = []
layer_ncells = []
layer_mat_ids = []

dz_res = [  0.01751282,0.02757897,0.04547003,0.07496741,0.1236004,0.2037826,0.3359806,0.5539384,0.91329,
         1.505761,2.48258,4.093082,6.748351,11.12615,13.85115] # cell center to center distance

# ZSOI variable in ELM simulations [soil depth]
z_res = [0.007100635, 0.027925, 0.06225858,0.1188651,0.2121934,0.3660658,0.6197585,1.038027,1.727635,2.864607, 4.739157]

z_depth = np.sum(z_res)

print z_depth
ind = 1001
for i,z in enumerate(z_res):
    layer_types.append('constant')
    layer_data.append(z)
    layer_ncells.append(1)
    if i ==1:
        ind = 1002
    if (i ==2) :
        ind = 1003
    #print ind
    layer_mat_ids.append(ind)

#layer_types.append('constant')
#layer_data.append(z_res[-1]) # bottom location
"""
layer_types.append('snapped')
layer_data.append(-z_depth) # bottom location
"""
#layer_ncells.append(1)
#layer_mat_ids.append(ind)
print layer_data
m3 = meshing_ats.Mesh3D.extruded_Mesh2D(m2, layer_types, 
                                        layer_data, 
                                        layer_ncells, 
                                        layer_mat_ids)
m3.write_exodus(outfile + mesh_name + ".exo")
#m3.write_exodus(outfile + "coweeta-hillslope-clmres.exo")
# Out:
# 11.783593015000001
# [0.007100635, 0.027925, 0.06225858, 0.1188651, 0.2121934, 0.3660658, 0.6197585, 1.038027, 1.727635, 2.864607, 4.739157]
#
# You are using exodus.py v 1.05 (beta-cmake), a python wrapper of some of the exodus II library.
#
# Copyright (c) 2013, 2014, 2015, 2016, 2017 National Technology &
# Engineering Solutions of Sandia, LLC (NTESS).  Under the terms of
# Contract DE-NA0003525 with NTESS, the U.S. Government retains certain
# rights in this software.
#
# Opening exodus file: /Users/ajc/Desktop/ATS/CoweetaLTER/mesh/coweeta_basin2-fine.exo
# Closing exodus file: /Users/ajc/Desktop/ATS/CoweetaLTER/mesh/coweeta_basin2-fine.exo
