# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# for Stan
import matplotlib.image as mpimg
fig, ax = plt.subplots(1,3, figsize=(18,6), facecolor='w', edgecolor='k',gridspec_kw={'width_ratios':[1,1,1]})
fig.subplots_adjust(hspace =.02, wspace=1.02)

plt.tight_layout()
Imges = ['model_domain.png', 'water_fluxes.png', 'water_table_sensitivity.png']
Imges = ['model_domain.png','ALT-x0m.png','soil_temperature.png']
for i,im in enumerate(Imges):
    #img1='/Users/ajc/Documents/ResearchDocuments/NGEE/hydraulic_conductivity/%s'%im
    img1='/Users/ajc/Documents/ResearchDocuments/NGEE/snow_timing/%s'%im
    img2 = mpimg.imread(img1)
    ax[i].imshow(img2)
    ax[i].axis('off')
plt.tight_layout()
#plt.savefig('/Users/ajc/Documents/ResearchDocuments/NGEE/hydraulic_conductivity/'+'fig.jpeg', bbox_inches='tight', dpi=600)
#plt.savefig('/Users/ajc/Documents/ResearchDocuments/NGEE/snow_timing/'+'fig.jpeg', bbox_inches='tight', dpi=800)

# %%
# for Eric
import matplotlib.image as mpimg
fig, ax = plt.subplots(1,3, figsize=(12,6), facecolor='w', edgecolor='k',gridspec_kw={'width_ratios':[1,1,1]})
fig.subplots_adjust(hspace =.0, wspace=.0)

plt.tight_layout()
outfile='/Users/ajc/Core/PostProcessing/ReactiveTransport/Hyporheic/Coweeta/June11/'
Imges = ['Wrun1E/fig-discharge.png','Crun1A/Tracer1/fig-3.png','Crun1A/Tracer1/fig-110.png',]
for i,im in enumerate(Imges):
    #img1='/Users/ajc/Documents/ResearchDocuments/NGEE/hydraulic_conductivity/%s'%im
    img1=outfile+'%s'%im
    img2 = mpimg.imread(img1)
    ax[i].imshow(img2)
    ax[i].axis('off')
plt.tight_layout()#pad=0.4, w_pad=0.5, h_pad=1.0)
#plt.savefig('/Users/ajc/Documents/ResearchDocuments/NGEE/hydraulic_conductivity/'+'fig.jpeg', bbox_inches='tight', dpi=600)
plt.savefig(outfile+'eric.jpeg', bbox_inches='tight', dpi=800)
